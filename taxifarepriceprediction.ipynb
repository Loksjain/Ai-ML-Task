# %%
import pandas as pd
train=pd.read_csv("train.csv")
train.head()
# Out:
#    trip_duration  distance_traveled  num_of_passengers    fare  tip  \
# 0          748.0               2.75                1.0   75.00   24
# 1         1187.0               3.43                1.0  105.00   24
# 2          730.0               3.12                1.0   71.25    0
# 3          671.0               5.63                3.0   90.00    0
# 4          329.0               2.09                1.0   45.00   12
#
#    miscellaneous_fees  total_fare  surge_applied
# 0               6.300     105.300              0
# 1              13.200     142.200              0
# 2              26.625      97.875              1
# 3               9.750      99.750              0
# 4              13.200      70.200              0

# %%
test=pd.read_csv("test.csv")
test.head()
# Out:
#    trip_duration  distance_traveled  num_of_passengers  fare  tip  \
# 0         1076.0               4.18                1.0     0    0
# 1          429.0               1.48                4.0     0    0
# 2          856.0               4.15                1.0     0   24
# 3          622.0               3.22                1.0     0   15
# 4          507.0               3.98                1.0     0    0
#
#    miscellaneous_fees  total_fare  surge_applied
# 0              13.500           0              0
# 1              13.500           0              0
# 2               6.000           0              0
# 3               5.625           0              0
# 4               2.250           0              0

# %%
x_train=train.drop(["fare","total_fare"],axis="columns")
x_train.head()
# Out:
#    trip_duration  distance_traveled  num_of_passengers  tip  \
# 0          748.0               2.75                1.0   24
# 1         1187.0               3.43                1.0   24
# 2          730.0               3.12                1.0    0
# 3          671.0               5.63                3.0    0
# 4          329.0               2.09                1.0   12
#
#    miscellaneous_fees  surge_applied
# 0               6.300              0
# 1              13.200              0
# 2              26.625              1
# 3               9.750              0
# 4              13.200              0

# %%
y_train=train["fare"]
y_train.head()
# Out:
# 0     75.00
# 1    105.00
# 2     71.25
# 3     90.00
# 4     45.00
# Name: fare, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
reg.score(x_train,y_train)
# Out:
# 0.16525850431438738

# %%
test=pd.read_csv("test.csv")
test.head()
# Out:
#    trip_duration  distance_traveled  num_of_passengers  fare  tip  \
# 0         1076.0               4.18                1.0     0    0
# 1          429.0               1.48                4.0     0    0
# 2          856.0               4.15                1.0     0   24
# 3          622.0               3.22                1.0     0   15
# 4          507.0               3.98                1.0     0    0
#
#    miscellaneous_fees  total_fare  surge_applied
# 0              13.500           0              0
# 1              13.500           0              0
# 2               6.000           0              0
# 3               5.625           0              0
# 4               2.250           0              0

# %%
ndf=pd.read_csv("taxi.csv")
ndf.head()
# Out:
#                 pickup              dropoff  passengers  distance  fare   tip  \
# 0  2019-03-23 20:21:09  2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1  2019-03-04 16:11:55  2019-03-04 16:19:00           1      0.79   5.0  0.00
# 2  2019-03-27 17:53:01  2019-03-27 18:00:25           1      1.37   7.5  2.36
# 3  2019-03-10 01:23:59  2019-03-10 01:49:51           1      7.70  27.0  6.15
# 4  2019-03-30 13:27:42  2019-03-30 13:37:14           3      2.16   9.0  1.10
#
#    tolls  total   color      payment            pickup_zone  \
# 0    0.0  12.95  yellow  credit card        Lenox Hill West
# 1    0.0   9.30  yellow         cash  Upper West Side South
# 2    0.0  14.16  yellow  credit card          Alphabet City
# 3    0.0  36.95  yellow  credit card              Hudson Sq
# 4    0.0  13.40  yellow  credit card           Midtown East
#
#             dropoff_zone pickup_borough dropoff_borough
# 0    UN/Turtle Bay South      Manhattan       Manhattan
# ...

# %%
ndf=ndf.drop(["pickup","dropoff","color","payment","pickup_zone","dropoff_zone","pickup_borough","dropoff_borough",],axis="columns")

# %%
ndf.head()
# Out:
#    passengers  distance  fare   tip  tolls  total
# 0           1      1.60   7.0  2.15    0.0  12.95
# 1           1      0.79   5.0  0.00    0.0   9.30
# 2           1      1.37   7.5  2.36    0.0  14.16
# 3           1      7.70  27.0  6.15    0.0  36.95
# 4           3      2.16   9.0  1.10    0.0  13.40

# %%
xdf=ndf.drop(["total"],axis="columns")
xdf.head()
# Out:
#    passengers  distance  fare   tip  tolls
# 0           1      1.60   7.0  2.15    0.0
# 1           1      0.79   5.0  0.00    0.0
# 2           1      1.37   7.5  2.36    0.0
# 3           1      7.70  27.0  6.15    0.0
# 4           3      2.16   9.0  1.10    0.0

# %%
ydf=ndf.total
ydf.head()
# Out:
# 0    12.95
# 1     9.30
# 2    14.16
# 3    36.95
# 4    13.40
# Name: total, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(xdf, ydf, test_size=0.2)
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.score(x_test,y_test)
# Out:
# 0.9938337306824109
